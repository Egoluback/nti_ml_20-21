# %%
import pandas as pd
import numpy as np
import requests
from io import StringIO

# %%
def get_df(link):
  path = 'https://drive.google.com/uc?export=download&id='+link.split('/')[-2]
  return pd.read_csv(path)

# %%
url_train = 'https://drive.google.com/file/d/14C3fWUQk9fuv_BaFFN87ZckAPDDsuFd2/view'
url_test = 'https://drive.google.com/file/d/1EULSxKCsdmY6XLBbYzXsrX2FBzx1cdCB/view'

# %%
df_train = get_df(url_train)
df_train.head()
# Out:
#    Unnamed: 0   Год   Месяц   День                Время         Канал  \
# 0           0  2018  Ноябрь  Day 1  05:00:00 - 06:00:00  ПЕРВЫЙ КАНАЛ
# 1           1  2018  Ноябрь  Day 1  06:00:00 - 07:00:00  ПЕРВЫЙ КАНАЛ
# 2           2  2018  Ноябрь  Day 1  07:00:00 - 08:00:00  ПЕРВЫЙ КАНАЛ
# 3           3  2018  Ноябрь  Day 1  08:00:00 - 09:00:00  ПЕРВЫЙ КАНАЛ
# 4           4  2018  Ноябрь  Day 1  09:00:00 - 10:00:00  ПЕРВЫЙ КАНАЛ
#
#    Все 18+_TVR  Все 55+_TVR  Все 18+_Share  Все 55+_Share  \
# 0         0.21         0.12           5.23           2.00
# 1         0.71         0.33          11.23           4.90
# 2         1.10         0.59          14.58           6.49
# 3         0.96         0.94          10.41           7.41
# 4         1.94         3.81          17.54          21.51
#
#              Дата_День  next_day                 Дата
# 0  2018-11-01 00:00:00     False  2018-11-01 05:00:00
# 1  2018-11-01 00:00:00     False  2018-11-01 06:00:00
# 2  2018-11-01 00:00:00     False  2018-11-01 07:00:00
# 3  2018-11-01 00:00:00     False  2018-11-01 08:00:00
# 4  2018-11-01 00:00:00     False  2018-11-01 09:00:00

# %%
df_test = get_df(url_test)
df_test.head()
# Out:
#    Unnamed: 0   Год   Месяц   День                Время         Канал  \
# 0          19  2018  Ноябрь  Day 1  24:00:00 - 25:00:00  ПЕРВЫЙ КАНАЛ
# 1          20  2018  Ноябрь  Day 1  25:00:00 - 26:00:00  ПЕРВЫЙ КАНАЛ
# 2          21  2018  Ноябрь  Day 1  26:00:00 - 27:00:00  ПЕРВЫЙ КАНАЛ
# 3          22  2018  Ноябрь  Day 1  27:00:00 - 28:00:00  ПЕРВЫЙ КАНАЛ
# 4          23  2018  Ноябрь  Day 1  28:00:00 - 29:00:00  ПЕРВЫЙ КАНАЛ
#
#    Все 18+_TVR  Все 55+_TVR  Все 18+_Share  Все 55+_Share  \
# 0          NaN          NaN            NaN            NaN
# 1          NaN          NaN            NaN            NaN
# 2          NaN          NaN            NaN            NaN
# 3          NaN          NaN            NaN            NaN
# 4          NaN          NaN            NaN            NaN
#
#              Дата_День  next_day                 Дата
# 0  2018-11-02 00:00:00      True  2018-11-02 00:00:00
# 1  2018-11-02 00:00:00      True  2018-11-02 01:00:00
# 2  2018-11-02 00:00:00      True  2018-11-02 02:00:00
# 3  2018-11-02 00:00:00      True  2018-11-02 03:00:00
# 4  2018-11-02 00:00:00      True  2018-11-02 04:00:00

# %%
df_train.shape
# Out:
# (70080, 13)

# %%
df_test.shape
# Out:
# (17640, 13)

# %%
df_train[df_train['День'] != 'Day 1'][:10]
# Out:
#      Unnamed: 0   Год   Месяц   День                Время         Канал  \
# 95          139  2018  Ноябрь  Day 2  24:00:00 - 25:00:00  ПЕРВЫЙ КАНАЛ
# 96          140  2018  Ноябрь  Day 2  25:00:00 - 26:00:00  ПЕРВЫЙ КАНАЛ
# 97          141  2018  Ноябрь  Day 2  26:00:00 - 27:00:00  ПЕРВЫЙ КАНАЛ
# 98          142  2018  Ноябрь  Day 2  27:00:00 - 28:00:00  ПЕРВЫЙ КАНАЛ
# 99          143  2018  Ноябрь  Day 2  28:00:00 - 29:00:00  ПЕРВЫЙ КАНАЛ
# 100         163  2018  Ноябрь  Day 2  24:00:00 - 25:00:00      РОССИЯ 1
# 101         164  2018  Ноябрь  Day 2  25:00:00 - 26:00:00      РОССИЯ 1
# 102         165  2018  Ноябрь  Day 2  26:00:00 - 27:00:00      РОССИЯ 1
# 103         166  2018  Ноябрь  Day 2  27:00:00 - 28:00:00      РОССИЯ 1
# 104         167  2018  Ноябрь  Day 2  28:00:00 - 29:00:00      РОССИЯ 1
#
#      Все 18+_TVR  Все 55+_TVR  Все 18+_Share  Все 55+_Share  \
# 95          2.11         2.99           8.52           8.63
# 96          0.85         0.61           5.60           3.05
# 97          0.18         0.06           1.92           0.47
# 98          0.14         0.00           1.97           0.00
# 99          0.30         0.00           5.74           0.00
# 100         4.04         8.05          16.28          23.25
# 101         1.82         3.56          11.91          17.94
# 102         0.71         2.00           7.54          15.81
# 103         0.56         1.57           7.71          16.54
# 104         0.36         1.01           6.80          16.27
#
#                Дата_День  next_day                 Дата
# 95   2018-11-03 00:00:00      True  2018-11-03 00:00:00
# 96   2018-11-03 00:00:00      True  2018-11-03 01:00:00
# 97   2018-11-03 00:00:00      True  2018-11-03 02:00:00
# 98   2018-11-03 00:00:00      True  2018-11-03 03:00:00
# 99   2018-11-03 00:00:00      True  2018-11-03 04:00:00
# 100  2018-11-03 00:00:00      True  2018-11-03 00:00:00
# 101  2018-11-03 00:00:00      True  2018-11-03 01:00:00
# 102  2018-11-03 00:00:00      True  2018-11-03 02:00:00
# 103  2018-11-03 00:00:00      True  2018-11-03 03:00:00
# 104  2018-11-03 00:00:00      True  2018-11-03 04:00:00

# %%
df_train["Канал"].value_counts().index
# Out:
# Index(['РЕН ТВ', 'СТС', 'ТНТ', 'РОССИЯ 1', 'ПЕРВЫЙ КАНАЛ'], dtype='object')

# %%
df_train.drop(columns= 'Unnamed: 0', inplace=True)

# %%
df_train.groupby(['Год', 'Месяц', 'День']).mean()
# Out:
#                      Все 18+_TVR  Все 55+_TVR  Все 18+_Share  Все 55+_Share  \
# Год  Месяц   День
# 2018 Декабрь Day 1      1.535053     2.422632       6.334211       6.797684
#              Day 10     1.413250     2.164583       7.960083       8.172500
#              Day 11     1.324917     2.182417       7.270667       7.394250
#              Day 12     1.364333     2.125083       7.442167       7.518167
#              Day 13     1.447583     2.219833       7.556750       8.119417
# ...                          ...          ...            ...            ...
# 2020 Январь  Day 5      0.885200     1.302000       7.301600       8.016400
#              Day 6      1.266083     1.855917       6.401417       6.452000
#              Day 7      1.237750     1.613417       5.845167       5.322417
#              Day 8      1.531500     1.910833       7.090750       6.139667
#              Day 9      1.181583     1.702417       7.491083       7.261500
#
#                      next_day
# Год  Месяц   День
# 2018 Декабрь Day 1   0.000000
#              Day 10  0.208333
#              Day 11  0.208333
#              Day 12  0.208333
#              Day 13  0.208333
# ...                       ...
# 2020 Январь  Day 5   1.000000
#              Day 6   0.208333
#              Day 7   0.208333
#              Day 8   0.208333
#              Day 9   0.208333
#
# [712 rows x 5 columns]

# %%
#посмотреть средней для кажого канала по месяцу, дню недели

# %%
month_mean = {chanel : df_train.groupby(['Год', 'Месяц']).mean() for chanel in df_train["Канал"].value_counts().index}

# %%
month_mean['ПЕРВЫЙ КАНАЛ']
# Out:
#                Все 18+_TVR  Все 55+_TVR  Все 18+_Share  Все 55+_Share  \
# Год  Месяц
# 2018 Декабрь      1.480683     2.242300       7.611177       7.710993
#      Ноябрь       1.392856     2.136208       7.659428       7.848977
# 2019 Август       0.977348     1.483775       6.960851       7.102525
#      Апрель       1.272284     1.908557       7.628049       7.619772
#      Декабрь      1.461236     2.233986       7.757115       7.631090
#      Июль         1.070964     1.605816       7.528086       7.471471
#      Июнь         1.014137     1.510150       7.428663       7.297530
#      Май          1.096496     1.563451       7.156231       6.932125
#      Март         1.348090     1.940458       7.198406       6.964857
#      Ноябрь       1.377865     2.050938       7.564347       7.471420
#      Октябрь      1.310851     1.943193       7.814463       7.746374
#      Сентябрь     1.118872     1.617813       7.303649       7.230750
#      Февраль      1.365531     2.001767       7.412566       7.124031
#      Январь       1.382915     2.038927       7.197946       7.175829
# 2020 Август       1.010872     1.602522       7.596010       7.995990
#      Апрель       1.471988     2.193825       7.313489       7.098374
#      Июль         1.020232     1.632410       7.338159       7.629072
#      Июнь         1.008115     1.532080       7.320337       7.436333
#      Май          1.154819     1.800072       7.035377       7.309120
#      Март         1.354448     1.937440       7.565548       7.270715
#      Октябрь      1.250722     1.938847       7.639545       7.736278
#      Сентябрь     1.124723     1.754980       7.696610       7.886203
#      Февраль      1.334417     1.844161       7.472071       7.063174
#      Январь       1.371755     1.951970       7.565792       7.120672
#
#                next_day
# Год  Месяц
# 2018 Декабрь   0.208333
#      Ноябрь    0.208333
# 2019 Август    0.208333
#      Апрель    0.201401
#      Декабрь   0.208333
#      Июль      0.215760
#      Июнь      0.208333
#      Май       0.208333
#      Март      0.215146
#      Ноябрь    0.208333
#      Октябрь   0.208333
#      Сентябрь  0.208333
#      Февраль   0.208333
#      Январь    0.202399
# 2020 Август    0.208333
#      Апрель    0.214395
#      Июль      0.214626
#      Июнь      0.200765
#      Май       0.208333
#      Март      0.201401
#      Октябрь   0.208333
#      Сентябрь  0.208333
#      Февраль   0.215760
#      Январь    0.201681

# %%
def code_year(year):
  return (6 + year % 100 + (year % 100) // 4) % 7

# %%
def code_month(month):
  if month == 'Январь' or month == 'Октябрь':
    return 1
  elif month == 'Май':
    return 2
  elif month == 'Август':
    return 3
  elif month == 'Февраль' or month == 'Март' or month == 'Ноябрь':
    return 4
  elif month == 'Июнь':
    return 5
  elif month == 'Декабрь' or month == 'Сентябрь':
    return 6
  else:
    return 0

# %%
def code_day(day):
  return int(day.split()[1])

# %%
len(df_train)
# Out:
# 70080

# %%
df_train['День недели'] = pd.Series([(code_day(df_train['День'][i]) + code_month(df_train['Месяц'][i]) + code_year(df_train['Год'][i])) % 7 for i in range(len(df_train))])

# %%
day_of_week_chanel = {chanel : df_train.groupby(['Год', 'День недели']).mean() for chanel in df_train['Канал'].value_counts().index}

# %%
day_of_week_chanel['СТС']
# Out:
#                   Все 18+_TVR  Все 55+_TVR  Все 18+_Share  Все 55+_Share  \
# Год  День недели
# 2018 0               1.430762     2.135833       7.008440       7.212857
#      1               1.561286     2.261190       7.037679       7.036762
#      2               1.531787     2.268831       8.259865       8.373843
#      3               1.387519     2.215112       7.919198       8.073594
#      4               1.401288     2.182049       7.858491       7.943178
#      5               1.420092     2.255373       7.880052       8.236601
#      6               1.291586     1.943910       7.328000       7.402486
# 2019 0               1.151793     1.593629       6.501073       6.221368
#      1               1.298372     1.781628       6.576474       6.421457
#      2               1.222735     1.874899       7.803574       7.851920
#      3               1.293137     1.985154       7.849326       7.868375
#      4               1.220009     1.855495       7.696595       7.661545
#      5               1.238488     1.881985       7.771288       7.693533
#      6               1.241486     1.850042       7.701333       7.502329
# 2020 0               1.171477     1.730040       7.110119       6.966197
#      1               1.255655     1.768005       6.905765       6.794879
#      2               1.209866     1.809112       7.436419       7.464097
#      3               1.214658     1.844635       7.674726       7.744810
#      4               1.183017     1.820968       7.552096       7.652527
#      5               1.216135     1.875148       7.677297       7.706059
#      6               1.227578     1.904384       7.800108       7.842796
#
#                   next_day
# Год  День недели
# 2018 0            0.208333
#      1            0.208333
#      2            0.252809
#      3            0.187166
#      4            0.184049
#      5            0.130719
#      6            0.315315
# 2019 0            0.204387
#      1            0.208333
#      2            0.220220
#      3            0.181818
#      4            0.234205
#      5            0.212150
#      6            0.200765
# 2020 0            0.208333
#      1            0.232558
#      2            0.203851
#      3            0.199063
#      4            0.208333
#      5            0.213018
#      6            0.194346
